# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize = (10,4) , dpi = 150)

sns.boxplot(data = data , y = "math score" , x = "test preparation course");

# %%
plt.figure(figsize = (10,4) , dpi = 150)

sns.boxplot(data = data , y = "math score" , x = "parental level of education");

# %%
plt.figure(figsize = (10,4) , dpi = 150)

sns.boxplot(data = data , y = "math score" , x = "parental level of education",
           hue = "test preparation course");

# %%
plt.figure(figsize = (10,4) , dpi = 150)

sns.boxplot(data = data , y = "math score" , x = "parental level of education",
           hue = "test preparation course")

plt.legend(bbox_to_anchor = (1,1))

# %%
plt.figure(figsize = (10,4) , dpi = 150)

sns.boxplot(data = data , y = "math score" , x = "parental level of education",
           hue = "test preparation course" , palette= 'Set2' )

plt.legend(bbox_to_anchor = (1,1))

# %% [markdown]
# ### Violinplot

# %%
plt.figure(figsize = (10,4) , dpi = 150)

sns.violinplot(data = data , y = "math score" , x = "parental level of education", 
              alpha = 0.2);

# %%
plt.figure(figsize = (10,4) , dpi = 150)

sns.violinplot(data = data , y = "math score" , x = "parental level of education",
           hue = "test preparation course" , palette= 'Set2' )

plt.legend(bbox_to_anchor = (1,1));

# %% [markdown]
# ### BOXEN PLOT

# %%
plt.figure(figsize = ( 5,3 ) , dpi = 150)


sns.boxenplot(data = data , y = "math score" , x ="test preparation course")
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='math score'>

# %%
plt.figure(figsize = ( 5,3 ) , dpi = 150)


sns.boxenplot(data = data , y = "math score" , x ="test preparation course" , hue = "gender" , palette= "Set2")

plt.legend(bbox_to_anchor = (1,1))

# %%
plt.figure(figsize = ( 5,3 ) , dpi = 150)


sns.boxplot(data = data , y = "math score" , x ="test preparation course" , hue = "gender" , palette= "Set2")

plt.legend(bbox_to_anchor = (1,1))

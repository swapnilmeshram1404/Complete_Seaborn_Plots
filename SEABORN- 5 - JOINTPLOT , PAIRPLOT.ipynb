# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
plt.figure( dpi = 150)

sns.jointplot(data = data , x = "math score" , y = "reading score");

# %%
plt.figure( dpi = 150)

sns.jointplot(data = data , x = "math score" , y = "reading score" , alpha = 0.2);

# %%
plt.figure( dpi = 150)

sns.jointplot(data = data , x = "math score" , y = "reading score" , kind = "hex");

# %%
plt.figure( dpi = 150)

sns.jointplot(data = data , x = "math score" , y = "reading score" , kind = "hist");

# %%
plt.figure( dpi = 150)

sns.jointplot(data = data , x = "math score" , y = "reading score" , kind = "kde");

# %%
plt.figure( dpi = 150)

sns.jointplot(data = data , x = "math score" , y = "reading score" , kind = "kde", shade = True);

# %% [markdown]
# ### WITH HUE

# %%
plt.figure( dpi = 150)

sns.jointplot(data = data , x = "math score" , y = "reading score" , hue = "gender", palette = "ocean");

# %% [markdown]
# ### PAIR PLOT

# %%
plt.figure(dpi = 150)

sns.pairplot(data = data)

# %%
plt.figure(dpi = 150)

sns.pairplot(data = data , hue = "gender", palette = "ocean")

# %%
### to remove duplicate plots set corner = True

# %%
plt.figure(dpi = 150)

sns.pairplot(data = data , hue = "gender", palette = "ocean", corner = True)

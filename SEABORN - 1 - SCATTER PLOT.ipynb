# %% [markdown]
# ### SCATTER PLOT

# %% [markdown]
# Scatter plot is used to plot relationship between two continuous variables.
#
# There are two types of variables that we studied, 1) Discrete and 2) continuous
#
# example of continuous variables are:
#
#     Height, Age, salary, prices etc

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
data
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %% [markdown]
# ### Finding Relationship Between Salary and Sales

# %%
plt.figure(figsize = (10 , 4) , dpi = 200)

sns.scatterplot(data = data , x = "salary" , y = "sales",
                 palette="tab20b", s = 100);

# %%
plt.figure(figsize = (10 , 4) , dpi = 200)

sns.scatterplot(data = data , x = "salary" , y = "sales",
                 palette="tab20b", s = 100, alpha = 0.2); 

#alpha value controls the opacity (alpha = 0 nothing will be visible and alpha = 1 means full opacity)

# %%
plt.figure(figsize = (10 , 4) , dpi = 200)

sns.scatterplot(data = data , x = "salary" , y = "sales",
                  s = 100 , style = "level of education" , 
               hue = "level of education", alpha = 0.5);
